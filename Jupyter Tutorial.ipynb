# %% [markdown]
# # My Jupyter Studio on IBM Watson Studio

# %% [markdown]
# <b>Rohan Menon</b>
#
# Sales

# %% [markdown]
# _I am interested in data science , because i want to find hidden insights_

# %% [markdown]
# ### The following cell does simple addition

# %%
1+2
# Out:
# 3

# %% [markdown]
# ***************
#
# - one
# - two
# - three
#
#
#
# 1 Apple
#
# 2 Ball
#
# 3 Cat
#
#
# > Blocked Quotes
#
#
# [Hyperlink](https://www.google.com/)
